# %% [markdown]
# # Proyek Analisis Data: Bike-Sharing-Dataset

# %% [markdown]
# Nama: Vania Adisaputri
#
# Email: adisaputrivania@gmail.com
#
# ID Dicoding:

# %% [markdown]
# # Menentukan Pertanyaan Bisnis

# %% [markdown]
# # Menyiapkan Semua Library yang Dibutuhkan

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
Data_Raw_Day= pd.read_csv("https://raw.githubusercontent.com/Vaniaadisa24/IDCamp/main/day.csv")
Data_Raw_Day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
Data_Raw_Hour= pd.read_csv("https://raw.githubusercontent.com/Vaniaadisa24/IDCamp/main/hour.csv")
Data_Raw_Hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Check Missing Value

# %%
Data_Raw_Day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
Data_Raw_Hour.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Check Duplicate Value

# %%
Data_Raw_Day.duplicated().sum()
# Out:
# 0

# %%
Data_Raw_Hour.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Check Outlier

# %% [markdown]
# ### Check Variable Type

# %%
Data_Raw_Day.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
Data_Raw_Hour.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ### Check Value

# %%
Data_Raw_Hour.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b083885e0191> in <module>
# ----> 1 Data_Raw_Hour.info()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2555                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2556                     size_qualifier = "+"
# -> 2557             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2558             lines.append(
#    2559                 "memory usage: {mem}\n".format(
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2653         )
#    2654         if index:
# -> 2655             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2656                 result
#    2657             )
#
# ...

# %%
Data_Raw_Day.dteday.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-1e5bb2beb91a> in <module>
# ----> 1 Data_Raw_Day.dteday.day
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'day'

# %%
import streamlit as st

# %%
st.write(
    """
    # My first app
    Hello, para calon praktisi data masa depan!
    """
)
# Out:
# 2023-11-23 22:30:45.797
# ...
#   command:
#
#     streamlit run C:\Users\Vania\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
st.linechart("")
